# %% [markdown]
# <a href="https://colab.research.google.com/github/tavochopadron-cyber/inteligencia-artificial/blob/main/Exposicion/Copia_de_expocicion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Multicapa
# ## Integrantes
# ## equipo 6

# %%
import numpy as np
import pandas as pd

# ========== CONJUNTO DE DATOS ==========
# Generar dataset de 500 prospectos para Grandes Ligas de Béisbol
n_muestras = 500

# Habilidades de bateo (rango competitivo): 70-100
bateo = np.random.randint(70, 101, (n_muestras, 6))

# Habilidades defensivas (rango competitivo): 65-95
defensa = np.random.randint(65, 96, (n_muestras, 6))

# Habilidades físicas y mentales (rango competitivo): 60-90
fisico_mental = np.random.randint(60, 91, (n_muestras, 6))

# Nombres de columnas específicas para béisbol de Grandes Ligas
columnas = [
    # Habilidades de bateo esenciales
    'potencia_bateo', 'contacto_bate', 'vision_zona', 'disciplina_plato', 'velocidad_bases', 'clutch_hitting',
    # Habilidades defensivas por posición
    'brazo_campo_externo', 'brazo_infield', 'range_defensivo', 'agarre_flys', 'velocidad_reaccion', 'doble_play',
    # Habilidades físicas y mentales
    'velocidad_carrera', 'resistencia_fisica', 'fuerza_brazo', 'mentalidad_competitiva', 'trabajo_equipo', 'liderazgo_diamante'
]

# Crear DataFrame con los 500 prospectos de béisbol
df = pd.DataFrame(np.concatenate([bateo, defensa, fisico_mental], axis=1), columns=columnas)

# ========== PREPARACIÓN DE ETIQUETAS ==========
# Calcular promedio por grupo y promedio total
prom_bateo = df[['potencia_bateo', 'contacto_bate', 'vision_zona', 'disciplina_plato', 'velocidad_bases', 'clutch_hitting']].mean(axis=1)
prom_defensivas = df[['brazo_campo_externo', 'brazo_infield', 'range_defensivo', 'agarre_flys', 'velocidad_reaccion', 'doble_play']].mean(axis=1)
prom_físicasymentales = df[['velocidad_carrera', 'resistencia_fisica', 'fuerza_brazo', 'mentalidad_competitiva', 'trabajo_equipo', 'liderazgo_diamante']].mean(axis=1)

# Promedio total = promedio de los 3 promedios
prom_total = (prom_bateo + prom_defensivas + prom_físicasymentales) / 3

# Etiqueta: 1 = apto si promedio total > 76
y = (prom_total > 76).astype(int)

# one-hot encoding: convierte [0,1] en [[1,0], [0,1]]
y = pd.get_dummies(y).values

# %%
# ========== DIVISIÓN DE DATOS ==========
from sklearn.model_selection import train_test_split
# Dividir datos: 80% entrenamiento, 20% prueba
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

# %%
# ========== escalonar ==========
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Estandarizar datos para mejor rendimiento de la red
X_train = scaler.fit_transform(X_train)  # Aprende y transforma entrenamiento
X_test = scaler.transform(X_test)        # Aplica misma transformación a prueba

# %%
# ========== RED NEURONAL ==========
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Crear modelo de red neuronal secuencial
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),  # Capa entrada + oculta 1
    Dense(32, activation='relu'),  # Capa oculta 2
    Dense(16, activation='relu'),  # Capa oculta 3
    Dense(2, activation='softmax') # Capa salida (2)
])

# Configurar optimizador Adam
adam = Adam(learning_rate=0.001)

# Compilar modelo: definir cómo aprende
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# ========== ENTRENAMIENTO ==========
history = modelo.fit(
    X_train, y_train,
    epochs=85,           # 100 pasadas completas por los datos
    batch_size=32,        # Procesa 32 muestras por lote
    validation_data=(X_test, y_test),  # Datos para validar durante entrenamiento
    verbose=1             # Muestra progreso
)
# Out:
# Epoch 1/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.0436 - loss: 1.2892 - val_accuracy: 0.3700 - val_loss: 0.7596
# Epoch 2/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6574 - loss: 0.6348 - val_accuracy: 0.9800 - val_loss: 0.3950
# Epoch 3/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9603 - loss: 0.3557 - val_accuracy: 0.9900 - val_loss: 0.2014
# Epoch 4/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9647 - loss: 0.2196 - val_accuracy: 0.9900 - val_loss: 0.1053
# Epoch 5/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9769 - loss: 0.1381 - val_accuracy: 0.9900 - val_loss: 0.0662
# Epoch 6/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9690 - loss: 0.1337 - val_accuracy: 0.9900 - val_loss: 0.0513
# Epoch 7/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9897 - loss: 0.0610 - val_accuracy: 0.9900 - val_loss: 0.0444
# Epoch 8/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9778 - loss: 0.0876 - val_accuracy: 0.9900 - val_loss: 0.0423
# Epoch 9/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9642 - loss: 0.1088 - val_accuracy: 0.9900 - val_loss: 0.0405
# Epoch 10/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9806 - loss: 0.0625 - val_accuracy: 0.9900 - val_loss: 0.0378
# Epoch 11/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9761 - loss: 0.0695 - val_accuracy: 0.9900 - val_loss: 0.0367
# Epoch 12/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9766 - loss: 0.0603 - val_accuracy: 0.9900 - val_loss: 0.0356
# Epoch 13/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9777 - loss: 0.0535 - val_accuracy: 0.9900 - val_loss: 0.0339
# Epoch 14/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9750 - loss: 0.0557 - val_accuracy: 0.9900 - val_loss: 0.0329
# Epoch 15/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9860 - loss: 0.0379 - val_accuracy: 0.9900 - val_loss: 0.0320
# Epoch 16/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9780 - loss: 0.0418 - val_accuracy: 0.9900 - val_loss: 0.0309
# Epoch 17/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9718 - loss: 0.0488 - val_accuracy: 0.9900 - val_loss: 0.0303
# Epoch 18/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9731 - loss: 0.0372 - val_accuracy: 0.9900 - val_loss: 0.0296
# Epoch 19/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.0217 - val_accuracy: 0.9900 - val_loss: 0.0287
# Epoch 20/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9973 - loss: 0.0255 - val_accuracy: 0.9900 - val_loss: 0.0283
# Epoch 21/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9922 - loss: 0.0260 - val_accuracy: 0.9800 - val_loss: 0.0286
# Epoch 22/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9950 - loss: 0.0209 - val_accuracy: 0.9800 - val_loss: 0.0280
# Epoch 23/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.0164 - val_accuracy: 0.9800 - val_loss: 0.0272
# Epoch 24/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9800 - val_loss: 0.0271
# Epoch 25/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9800 - val_loss: 0.0270
# Epoch 26/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.9800 - val_loss: 0.0274
# Epoch 27/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9800 - val_loss: 0.0270
# Epoch 28/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9800 - val_loss: 0.0265
# Epoch 29/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9800 - val_loss: 0.0259
# Epoch 30/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9800 - val_loss: 0.0256
# Epoch 31/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9800 - val_loss: 0.0250
# Epoch 32/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9800 - val_loss: 0.0245
# Epoch 33/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9900 - val_loss: 0.0239
# Epoch 34/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9900 - val_loss: 0.0235
# Epoch 35/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9900 - val_loss: 0.0231
# Epoch 36/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9900 - val_loss: 0.0230
# Epoch 37/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9900 - val_loss: 0.0230
# Epoch 38/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9900 - val_loss: 0.0227
# Epoch 39/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9900 - val_loss: 0.0222
# Epoch 40/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9900 - val_loss: 0.0219
# Epoch 41/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9900 - val_loss: 0.0217
# Epoch 42/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9900 - val_loss: 0.0214
# Epoch 43/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9900 - val_loss: 0.0211
# Epoch 44/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9900 - val_loss: 0.0209
# Epoch 45/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9900 - val_loss: 0.0208
# Epoch 46/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9900 - val_loss: 0.0206
# Epoch 47/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9900 - val_loss: 0.0205
# Epoch 48/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9900 - val_loss: 0.0204
# Epoch 49/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9900 - val_loss: 0.0203
# Epoch 50/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9900 - val_loss: 0.0201
# Epoch 51/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 9.6668e-04 - val_accuracy: 0.9900 - val_loss: 0.0201
# Epoch 52/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9900 - val_loss: 0.0200
# Epoch 53/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9900 - val_loss: 0.0199
# Epoch 54/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 9.7617e-04 - val_accuracy: 0.9900 - val_loss: 0.0198
# Epoch 55/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.7511e-04 - val_accuracy: 0.9900 - val_loss: 0.0198
# Epoch 56/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.9173e-04 - val_accuracy: 0.9900 - val_loss: 0.0198
# Epoch 57/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.4089e-04 - val_accuracy: 0.9900 - val_loss: 0.0197
# Epoch 58/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.9407e-04 - val_accuracy: 0.9900 - val_loss: 0.0196
# Epoch 59/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.9908e-04 - val_accuracy: 0.9900 - val_loss: 0.0195
# Epoch 60/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.1089e-04 - val_accuracy: 0.9900 - val_loss: 0.0193
# Epoch 61/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.9508e-04 - val_accuracy: 0.9900 - val_loss: 0.0193
# Epoch 62/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.5226e-04 - val_accuracy: 0.9900 - val_loss: 0.0192
# Epoch 63/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.6939e-04 - val_accuracy: 0.9900 - val_loss: 0.0192
# Epoch 64/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.6645e-04 - val_accuracy: 0.9900 - val_loss: 0.0193
# Epoch 65/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 5.5900e-04 - val_accuracy: 0.9900 - val_loss: 0.0191
# Epoch 66/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 4.3344e-04 - val_accuracy: 0.9900 - val_loss: 0.0192
# Epoch 67/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.8692e-04 - val_accuracy: 0.9900 - val_loss: 0.0190
# Epoch 68/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.1196e-04 - val_accuracy: 0.9900 - val_loss: 0.0190
# Epoch 69/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.9217e-04 - val_accuracy: 0.9900 - val_loss: 0.0189
# Epoch 70/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.1005e-04 - val_accuracy: 0.9900 - val_loss: 0.0188
# Epoch 71/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.8282e-04 - val_accuracy: 0.9900 - val_loss: 0.0189
# Epoch 72/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.4762e-04 - val_accuracy: 0.9900 - val_loss: 0.0188
# Epoch 73/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.0974e-04 - val_accuracy: 0.9900 - val_loss: 0.0188
# Epoch 74/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.0262e-04 - val_accuracy: 0.9900 - val_loss: 0.0188
# Epoch 75/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.6979e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 76/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.1673e-04 - val_accuracy: 0.9900 - val_loss: 0.0186
# Epoch 77/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.0416e-04 - val_accuracy: 0.9900 - val_loss: 0.0186
# Epoch 78/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.7922e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 79/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.4240e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 80/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.8369e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 81/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.6622e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 82/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.3420e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 83/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.2735e-04 - val_accuracy: 0.9900 - val_loss: 0.0188
# Epoch 84/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.7681e-04 - val_accuracy: 0.9900 - val_loss: 0.0187
# Epoch 85/85
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.5427e-04 - val_accuracy: 0.9900 - val_loss: 0.0188

# %%
# ========== MÉTRICAS Y EVALUACIÓN ==========
import matplotlib.pyplot as plt

# Graficar evolución de la pérdida durante entrenamiento
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

# Evaluar modelo final con datos de prueba
loss, acc = modelo.evaluate(X_test, y_test)
print(f"\nLoss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9908 - loss: 0.0170
#
# Loss: 0.0188  |  Accuracy: 0.9900

# %%
# ========== MATRIZ DE CONFUSIÓN ==========
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

# Predecir con el modelo entrenado
pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)  # Convertir probabilidades a clases (0 o 1)
y_true = np.argmax(y_test, axis=1)  # Convertir one-hot a clases

# Crear y mostrar matriz de confusión
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

# Calcular sensibilidad (recall) por clase
sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.00
# Apto: 1.00

# %%
# ========== ENCONTRAR AL PROXIMO ASPIRANTE ==========

# Usar solo los datos de prueba (X_test, y_test)
# Primero necesitamos revertir el escalado para obtener los valores originales
X_test_original = scaler.inverse_transform(X_test)

# Crear DataFrame con los datos de test originales
df_test = pd.DataFrame(X_test_original, columns=columnas)

# Calcular promedio total de habilidades para cada candidato en TEST
promedio_habilidades_test = df_test.mean(axis=1)

# Encontrar el índice del candidato con mayor promedio en TEST
indice_mejor_test = promedio_habilidades_test.idxmax()

# Obtener el candidato más apto del conjunto de TEST
mejor_candidato_test = df_test.loc[indice_mejor_test]

# Mostrar resultados del MEJOR en TEST
print(f" MEJOR CANDIDATO EN DATOS DE PRUEBA:")
print(f" Puntuación Total: {promedio_habilidades_test.max():.1f}")
print(f" Clasificación Real: {'Apto' if y_test[indice_mejor_test].argmax() == 1 else 'No Apto'}")
print(f" Predicción del Modelo: {'Apto' if modelo.predict(X_test)[indice_mejor_test].argmax() == 1 else 'No Apto'}")

print("\n HABILIDADES DESTACADAS:")
print(f"   Bateo: {df_test[['potencia_bateo', 'contacto_bate', 'vision_zona', 'disciplina_plato', 'velocidad_bases', 'clutch_hitting']].mean(axis=1)[indice_mejor_test]:.1f}")
print(f"   Defensa: {df_test[['brazo_campo_externo', 'brazo_infield', 'range_defensivo', 'agarre_flys', 'velocidad_reaccion', 'doble_play']].mean(axis=1)[indice_mejor_test]:.1f}")
print(f"   Físico/Mental: {df_test[['velocidad_carrera', 'resistencia_fisica', 'fuerza_brazo', 'mentalidad_competitiva', 'trabajo_equipo', 'liderazgo_diamante']].mean(axis=1)[indice_mejor_test]:.1f}")
# Out:
#  MEJOR CANDIDATO EN DATOS DE PRUEBA:
#  Puntuación Total: 85.8
#  Clasificación Real: Apto
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#  Predicción del Modelo: Apto
#
#  HABILIDADES DESTACADAS:
#    Bateo: 88.8
#    Defensa: 86.7
#    Físico/Mental: 82.0
